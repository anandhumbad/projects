# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Anand Humbad
# student

# %% [markdown]
# I am interested in data science because I love  deriving insights from data and data visualisations .

# %% [markdown]
# ### The following code will print two strings.

# %%
print("ANAND"+" "+"HUMBAD")
# Out:
# ANAND HUMBAD

# %% [markdown]
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |

# %% [markdown]
# top sports
# * football
# * cricket
# * rugby
# * volleyball

# %% [markdown]
# ![Screenshot%202022-08-24%20231658.png](attachment:Screenshot%202022-08-24%20231658.png)
